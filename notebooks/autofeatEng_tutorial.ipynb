# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

clients = pd.read_csv('../input/clients.csv', parse_dates=["joined"])
loans = pd.read_csv('../input/loans.csv', parse_dates=["loan_start", "loan_end"])
payments = pd.read_csv('../input/payments.csv' , parse_dates=["payment_date"])

# %%
clients.head(3)
# Out:
#    client_id     joined  income  credit_score
# 0      46109 2002-04-16  172677           527
# 1      49545 2007-11-14  104564           770
# 2      41480 2013-03-11  122607           585

# %%
loans.head(3)
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 0      46109      home        13672       0    10243 2002-04-16 2003-12-20
# 1      46109    credit         9794       0    10984 2003-10-21 2005-07-17
# 2      46109      home        12734       1    10990 2006-02-01 2007-07-05
#
#    rate
# 0  2.15
# 1  1.25
# 2  0.68

# %%
payments.head(3)
# Out:
#    loan_id  payment_amount payment_date  missed
# 0    10243            2369   2002-05-31       1
# 1    10243            2439   2002-06-18       1
# 2    10243            2662   2002-06-29       0

# %%
import numpy as np
clients["join_month"] = clients["joined"].dt.month
clients["log_income"] = np.log(clients["income"])
clients.head(3)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739

# %%
stats = loans.groupby("client_id")["loan_amount"].agg(["mean", "max", "min"])
stats.columns = ["mean_loan_amount", "max_loan_amount", "min_loan_amount"]
stats.head(3)
# Out:
#            mean_loan_amount  max_loan_amount  min_loan_amount
# client_id
# 25707           7963.950000            13913             1212
# 26326           7270.062500            13464             1164
# 26695           7824.722222            14865             2389

# %%
clients_stats_merge = pd.merge(
    clients,
    stats,
    left_on="client_id",
    right_on="client_id",
    how="left",
)

clients_stats_merge.head(3)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      49545 2007-11-14  104564           770          11   11.557555
# 2      41480 2013-03-11  122607           585           3   11.716739
#
#    mean_loan_amount  max_loan_amount  min_loan_amount
# 0           8951.60            14049              559
# 1          10289.30            14971             3851
# 2           7894.85            14399              811

# %%
clients_stats_loans_merge = pd.merge(
    clients_stats_merge,
    loans,
    left_on="client_id",
    right_on="client_id",
    how="left",
)

clients_stats_loans_merge.head(3)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      46109 2002-04-16  172677           527           4   12.059178
# 2      46109 2002-04-16  172677           527           4   12.059178
#
#    mean_loan_amount  max_loan_amount  min_loan_amount loan_type  loan_amount  \
# 0            8951.6            14049              559      home        13672
# 1            8951.6            14049              559    credit         9794
# 2            8951.6            14049              559      home        12734
#
#    repaid  loan_id loan_start   loan_end  rate
# 0       0    10243 2002-04-16 2003-12-20  2.15
# 1       0    10984 2003-10-21 2005-07-17  1.25
# 2       1    10990 2006-02-01 2007-07-05  0.68

# %%
merge_all = pd.merge(
    clients_stats_loans_merge,
    payments,
    left_on="loan_id",
    right_on="loan_id",
    how="left",
)

merge_all.head(3)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      46109 2002-04-16  172677           527           4   12.059178
# 2      46109 2002-04-16  172677           527           4   12.059178
#
#    mean_loan_amount  max_loan_amount  min_loan_amount loan_type  loan_amount  \
# 0            8951.6            14049              559      home        13672
# 1            8951.6            14049              559      home        13672
# 2            8951.6            14049              559      home        13672
#
#    repaid  loan_id loan_start   loan_end  rate  payment_amount payment_date  \
# 0       0    10243 2002-04-16 2003-12-20  2.15            2369   2002-05-31
# 1       0    10243 2002-04-16 2003-12-20  2.15            2439   2002-06-18
# 2       0    10243 2002-04-16 2003-12-20  2.15            2662   2002-06-29
#
#    missed
# 0       1
# 1       1
# 2       0

# %%
stats_payment = merge_all.groupby("loan_id")["payment_amount"].agg(
    ["sum", "mean", "max", "min", "std", "var"]
)

stats_payment.columns = [
    "sum_payment_amount",
    "mean_payment_amount",
    "max_payment_amount",
    "min_payment_amount",
    "std_payment_amount",
    "var_payment_amount",
]

stats_payment.head(3)
# Out:
#          sum_payment_amount  mean_payment_amount  max_payment_amount  \
# loan_id
# 10009                  1996           332.666667                 394
# 10017                  9432          1179.000000                1446
# 10024                  6345           705.000000                 895
#
#          min_payment_amount  std_payment_amount  var_payment_amount
# loan_id
# 10009                   280           46.915527         2201.066667
# 10017                   994          155.324545        24125.714286
# 10024                   518          141.412517        19997.500000

# %%
merge_all_add_newft = pd.merge(
    merge_all,
    stats_payment,
    left_on="loan_id",
    right_on="loan_id",
    how="left",
)

merge_all_add_newft.head(3)
# Out:
#    client_id     joined  income  credit_score  join_month  log_income  \
# 0      46109 2002-04-16  172677           527           4   12.059178
# 1      46109 2002-04-16  172677           527           4   12.059178
# 2      46109 2002-04-16  172677           527           4   12.059178
#
#    mean_loan_amount  max_loan_amount  min_loan_amount loan_type  ...  rate  \
# 0            8951.6            14049              559      home  ...  2.15
# 1            8951.6            14049              559      home  ...  2.15
# 2            8951.6            14049              559      home  ...  2.15
#
#    payment_amount  payment_date missed sum_payment_amount  \
# 0            2369    2002-05-31      1              14008
# 1            2439    2002-06-18      1              14008
# 2            2662    2002-06-29      0              14008
#
#    mean_payment_amount  max_payment_amount min_payment_amount  \
# 0          2334.666667                2662               2027
# 1          2334.666667                2662               2027
# 2          2334.666667                2662               2027
#
#    std_payment_amount  var_payment_amount
# 0          212.940054        45343.466667
# 1          212.940054        45343.466667
# 2          212.940054        45343.466667
#
# [3 rows x 25 columns]

# %%
import featuretools as ft

# %%
es = ft.EntitySet(id="clients")

# %%
es = es.entity_from_dataframe(
    entity_id="clients",
    dataframe=clients,
    index="client_id",
    time_index="joined",
)

# %%
es = es.entity_from_dataframe(
    entity_id="loans",
    dataframe=loans,
    variable_types={"repaid": ft.variable_types.Categorical},
    index="loan_id",
    time_index="loan_start",
)

# %%
es = es.entity_from_dataframe(
    entity_id="payments",
    dataframe=payments,
    variable_types={"missed": ft.variable_types.Categorical},
    make_index=True,
    index="payment_id",
    time_index="payment_date",
)

# %%
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 6]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
es["clients"]
# Out:
# Entity: clients
#   Variables:
#     client_id (dtype: index)
#     joined (dtype: datetime_time_index)
#     income (dtype: numeric)
#     credit_score (dtype: numeric)
#     join_month (dtype: numeric)
#     log_income (dtype: numeric)
#   Shape:
#     (Rows: 25, Columns: 6)

# %%
es["loans"]
# Out:
# Entity: loans
#   Variables:
#     loan_id (dtype: index)
#     client_id (dtype: numeric)
#     loan_type (dtype: categorical)
#     loan_amount (dtype: numeric)
#     loan_start (dtype: datetime_time_index)
#     loan_end (dtype: datetime)
#     rate (dtype: numeric)
#     repaid (dtype: categorical)
#   Shape:
#     (Rows: 443, Columns: 8)

# %%
es["payments"]
# Out:
# Entity: payments
#   Variables:
#     payment_id (dtype: index)
#     loan_id (dtype: numeric)
#     payment_amount (dtype: numeric)
#     payment_date (dtype: datetime_time_index)
#     missed (dtype: categorical)
#   Shape:
#     (Rows: 3456, Columns: 5)

# %%
relation_client_loans = ft.Relationship(
    es["clients"]["client_id"],
    es["loans"]["client_id"],
)

es = es.add_relationship(relation_client_loans)

# %%
relation_loans_payments = ft.Relationship(
    es["loans"]["loan_id"],
    es["payments"]["loan_id"],
)

es = es.add_relationship(relation_loans_payments)

# %%
primitives = ft.list_primitives()
primitives[primitives["type"] == "aggregation"].head(10)
# Out:
#                name         type  dask_compatible  koalas_compatible  \
# 0            median  aggregation            False              False
# 1  avg_time_between  aggregation            False              False
# 2               sum  aggregation             True               True
# 3          num_true  aggregation             True              False
# 4             trend  aggregation            False              False
# 5               max  aggregation             True               True
# 6   time_since_last  aggregation            False              False
# 7               any  aggregation             True              False
# 8              mode  aggregation            False              False
# 9             count  aggregation             True               True
#
#                                          description
# 0  Determines the middlemost number in a list of ...
# 1  Computes the average number of seconds between...
# 2     Calculates the total addition, ignoring `NaN`.
# 3                Counts the number of `True` values.
# 4      Calculates the trend of a variable over time.
# 5  Calculates the highest value, ignoring `NaN` v...
# 6  Calculates the time elapsed since the last dat...
# 7       Determines if any value is 'True' in a list.
# 8       Determines the most commonly repeated value.
# 9  Determines the total number of values, excludi...

# %%
primitives[primitives["type"] == "transform"].head(10)
# Out:
#                                name       type  dask_compatible  \
# 22                             hour  transform             True
# 23                          cum_min  transform            False
# 24                              age  transform             True
# 25                divide_by_feature  transform             True
# 26                        cum_count  transform            False
# 27  scalar_subtract_numeric_feature  transform             True
# 28                        haversine  transform            False
# 29                        num_words  transform             True
# 30                         absolute  transform             True
# 31               add_numeric_scalar  transform             True
#
#     koalas_compatible                                        description
# 22               True           Determines the hour value of a datetime.
# 23              False                 Calculates the cumulative minimum.
# 24              False  Calculates the age in years as a floating poin...
# 25               True         Divide a scalar by each value in the list.
# 26              False                   Calculates the cumulative count.
# 27               True  Subtract each value in the list from a given s...
# 28              False  Calculates the approximate haversine distance ...
# 29               True  Determines the number of words in a string by ...
# 30               True           Computes the absolute value of a number.
# 31               True            Add a scalar to each value in the list.

# %%
features, feature_names = ft.dfs(
    entityset = es, 
    target_entity = 'clients', 
    agg_primitives = ['mean', 'max', 'percent_true', 'last'],
    trans_primitives = ['years', 'month', 'divide']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-60a58d41c0ec> in <module>
# ----> 1 features, feature_names = ft.dfs(
#       2     entityset = es,
#       3     target_entity = 'clients',
#       4     agg_primitives = ['mean', 'max', 'percent_true', 'last'],
#       5     trans_primitives = ['years', 'month', 'divide']
#
# ~/.conda/envs/cat-in-the-dat-ii/lib/python3.8/site-packages/featuretools/utils/entry_point.py in function_wrapper(*args, **kwargs)
#      38                     ep.on_error(error=e,
#      39                                 runtime=runtime)
# ---> 40                 raise e
#      41
#      42             # send return value
#
# ~/.conda/envs/cat-in-the-dat-ii/lib/python3.8/site-packages/featuretools/utils/entry_point.py in function_wrapper(*args, **kwargs)
#      30                 # call function
#      31                 start = time.time()
# ---> 32                 return_value = func(*args, **kwargs)
#      33                 runtime = time.time() - start
#      34             except Exception as e:
#
# ~/.conda/envs/cat-in-the-dat-ii/lib/python3.8/site-packages/featuretools/synthesis/dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, groupby_trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, primitive_options, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, n_jobs, dask_kwargs, verbose, return_variable_types, progress_callback, include_cutoff_time)
#     244         entityset = EntitySet("dfs", entities, relationships)
#     245
# --> 246     dfs_object = DeepFeatureSynthesis(target_entity, entityset,
#     247                                       agg_primitives=agg_primitives,
#     248                                       trans_primitives=trans_primitives,
#
# ~/.conda/envs/cat-in-the-dat-ii/lib/python3.8/site-packages/featuretools/synthesis/deep_feature_synthesis.py in __init__(self, target_entity_id, entityset, agg_primitives, trans_primitives, where_primitives, groupby_trans_primitives, max_depth, max_features, allowed_paths, ignore_entities, ignore_variables, primitive_options, seed_features, drop_contains, drop_exact, where_stacking_limit)
#     211         self.trans_primitives = []
#     212         for t in trans_primitives:
# --> 213             t = check_trans_primitive(t)
#     214             self.trans_primitives.append(t)
#     215         self.trans_primitives.sort()
#
# ~/.conda/envs/cat-in-the-dat-ii/lib/python3.8/site-packages/featuretools/synthesis/deep_feature_synthesis.py in check_trans_primitive(primitive)
#     925     if isinstance(primitive, str):
#     926         if primitive.lower() not in trans_prim_dict:
# --> 927             raise ValueError("Unknown transform primitive {}. ".format(primitive),
#     928                              "Call ft.primitives.list_primitives() to get",
#     929                              " a list of available primitives")
#
# ValueError: ('Unknown transform primitive years. ', 'Call ft.primitives.list_primitives() to get', ' a list of available primitives')

# %%
pd.DataFrame(features['MONTH(joined)'].head())

# %%
pd.DataFrame(features['MEAN(payments.payment_amount)'].head())

# %%
features.head()

# %%
pd.DataFrame(features['MEAN(loans.loan_amount)'].head(10))

# %%
pd.DataFrame(features['LAST(loans.MEAN(payments.payment_amount))'].head(10))

# %%
features, feature_names = ft.dfs(entityset=es, target_entity='clients', 
                                 max_depth = 2)

# %%
features.iloc[:, 4:].head()
